# %%
print("day1 of banking project")
# Out:
# day1 of banking project

# %%
spark

# %%
data = [
    (1,"Rahul"),
    (2,"Amit"),
    (3,"Neha")
]

df = spark.createDataFrame(
    data,
    ["id","name"]
)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>Rahul</td></tr><tr><td>2</td><td>Amit</td></tr><tr><td>3</td><td>Neha</td></tr></tbody></table></div>

# %%
data = [
    (1,"IT"),
    (2,"HR"),
    (3,"Sales")
]
dff = spark.createDataFrame(
    data,
    ["id","department"]
)

# %%
print(dff)
# Out:
# DataFrame[id: bigint, department: string]

# %%
display(dff)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>IT</td></tr><tr><td>2</td><td>HR</td></tr><tr><td>3</td><td>Sales</td></tr></tbody></table></div>
